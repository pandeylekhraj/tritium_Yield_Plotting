198.06261	0.6601846469	0.002393645538	0.0008318326551	0.002706757052			
209.70233	0.5744892318	0.002082937846	0.000723856432	0.00235540585			
222.02608	0.4983073825	0.001806723692	0.0006278673019	0.002043060268			
235.07408	0.4322256773	0.001567129846	0.0005446043534	0.001772125277			
246.53128	0.385977649	0.001399447385	0.0004863318377	0.001582508361			
258.54689	0.3424608756	0.001241667692	0.0004315007033	0.00140408959			
273.74114	0.2970468882	0.001077009231	0.0003742790792	0.001217892242			
287.08292	0.2656924481	0.0009633267692	0.0003347724846	0.001089339037			
298.22303	0.2376466759	0.0008616406154	0.0002994348116	0.0009743513711			
312.75803	0.2108473824	0.0007644738462	0.0002656677018	0.0008644742679			
"""

# %%
import pandas as pd
import numpy as np
from io import StringIO
import matplotlib.pyplot as plt

# Load the data into a DataFrame
data_io = StringIO(data)
df = pd.read_csv(data_io, delim_whitespace=True, header=None)

# Assign column names
df.columns = ['MWE', 'Scaled Number', 'Tritium Production Si', 'Tritium Production Ge',  'Co Production Cu','Tritium Production Si Neutron', 'Tritium Production Ge Neutron','Co Production Cu Neutron']

# Display the DataFrame
#print("DataFrame:\n", df.to_string(index=False))

# Extract columns for plotting
MWE = df['MWE']
scaled_number = df['Scaled Number']
tri_prod_Si = df['Tritium Production Si']
tri_prod_Si_neutron = df['Tritium Production Si Neutron']
tri_prod_Ge = df['Tritium Production Ge']
tri_prod_Ge_neutron = df['Tritium Production Ge Neutron']
co_prod_Cu = df['Co Production Cu']
co_prod_Cu_neutron = df['Co Production Cu Neutron']

# Create the plot
fig, ax1 = plt.subplots(figsize=(10, 6))

# Set y-axis to log scale
ax1.set_yscale("log")

# Plotting scatter points with specified colors and markers
scatter_si_mu_stop = ax1.scatter(MWE, tri_prod_Si, label="Si, μ-stop", color="blue", marker="o")
scatter_si_n = ax1.scatter(MWE, tri_prod_Si_neutron, label="Si, n", color="cyan", marker="s")
scatter_ge_mu_stop = ax1.scatter(MWE, tri_prod_Ge, label="Ge, μ-stop", color="green", marker="o")
scatter_ge_n = ax1.scatter(MWE, tri_prod_Ge_neutron, label="Ge, n", color="lime", marker="^")
scatter_cu_mu_stop = ax1.scatter(MWE, co_prod_Cu, label="Cu, μ-stop", color="red", marker="o")
scatter_cu_n = ax1.scatter(MWE, co_prod_Cu_neutron, label="Cu, n", color="orange", marker="x")

# Labeling axes
ax1.set_xlabel("MWE")
ax1.set_ylabel("Production Rates (per kg per day)")

# Add text at the top middle of ax1
ax1.text(150, 100, "Tritium Production in", ha='center', va='bottom', fontsize=12, fontweight='bold')

# Set the legend
legend = ax1.legend(loc="upper center", bbox_to_anchor=(0.5, 0.95), fontsize="small", ncol=1, frameon=False)

# Set the color of the legend text to match the plot markers
for text in legend.get_texts():
    label = text.get_text()
    if label == "Si, μ-stop":
        text.set_color("blue")
    elif label == "Si, n":
        text.set_color("cyan")
    elif label == "Ge, μ-stop":
        text.set_color("green")
    elif label == "Ge, n":
        text.set_color("lime")
    elif label == "Cu, μ-stop":
        text.set_color("red")
    elif label == "Cu, n":
        text.set_color("orange")

# Right y-axis for scaled number
ax2 = ax1.twinx()
ax2.set_yscale("log")  # Set right y-axis to log scale
right_color = "purple"
ax2.plot(MWE, scaled_number, label="Scaled Number", color=right_color, marker="x", linestyle='-')
ax2.set_ylabel("Scaled Number", color=right_color)
ax2.tick_params(axis='y', colors=right_color)  # Set tick colors on the right y-axis to match
ax2.spines['right'].set_color(right_color)     # Set right y-axis spine color to match
ax2.legend(lines2, labels2, loc="upper right", fontsize="small")
# Show plot
#plt.title("Production Rates and Scaled Number vs MWE (Log Scale)")
plt.show()

# %%
import matplotlib.pyplot as plt
# Create the plot
fig, ax1 = plt.subplots(figsize=(10, 6))

# Set y-axis to log scale
ax1.set_yscale("log")

# Plotting scatter points
ax1.scatter(MWE, tri_prod_Si, label="Si, μ-stop", color="blue", marker="o")
ax1.scatter(MWE, tri_prod_Si_neutron, label="Si, n", color="cyan", marker="s")
ax1.scatter(MWE, tri_prod_Ge, label="Ge, μ-stop", color="green", marker="o")
ax1.scatter(MWE, tri_prod_Ge_neutron, label="Ge, n", color="lime", marker="^")
ax1.scatter(MWE, co_prod_Cu, label="Cu, μ-stop", color="red", marker="o")
ax1.scatter(MWE, co_prod_Cu_neutron, label="Cu, n", color="orange", marker="x")

# Labeling axes
ax1.set_xlabel("MWE")
ax1.set_ylabel("Production Rates (per kg per day)")

# Add text at the top middle of ax1
ax1.text(150, 100, "Tritium Production in", ha='center', va='bottom', fontsize=12, fontweight='bold')

# Right y-axis for scaled number
ax2 = ax1.twinx()
ax2.set_yscale("log")  # Set right y-axis to log scale
right_color = "purple"
ax2.plot(MWE, scaled_number, label="Scaled Number", color=right_color, marker="x", linestyle='-')
ax2.set_ylabel("Scaled Number", color=right_color)
ax2.tick_params(axis='y', colors=right_color)  # Set tick colors on the right y-axis to match
ax2.spines['right'].set_color(right_color)     # Set right y-axis spine color to match

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc="upper center", bbox_to_anchor=(0.5, 0.95), fontsize="small", ncol=1, frameon=False)

# Show plot
plt.title("Production Rates and Scaled Number vs MWE (Log Scale)")
plt.show()

# %%
# Create the plot
fig, ax1 = plt.subplots(figsize=(10, 6))

# Set y-axis to log scale
ax1.set_yscale("log")

# Plotting scatter points with consistent colors and markers
ax1.scatter(MWE, tri_prod_Si, label="Si, μ-stop", color="blue", marker="o")
ax1.scatter(MWE, tri_prod_Si_neutron, label="Si, n", color="blue", marker="s")  # Same color as Si, μ-stop
ax1.scatter(MWE, tri_prod_Ge, label="Ge, μ-stop", color="green", marker="o")
ax1.scatter(MWE, tri_prod_Ge_neutron, label="Ge, n", color="green", marker="s")  # Same color as Ge, μ-stop
ax1.scatter(MWE, co_prod_Cu, label="Cu, μ-stop", color="red", marker="o")
ax1.scatter(MWE, co_prod_Cu_neutron, label="Cu, n", color="red", marker="s")  # Same color as Cu, μ-stop

# Labeling axes
ax1.set_xlabel("MWE")
ax1.set_ylabel("Production Rates (per kg per day)")

# Add text at the top middle of ax1
ax1.text(150, 100, "Tritium Production in", ha='center', va='bottom', fontsize=12, fontweight='bold')

# Right y-axis for scaled number
ax2 = ax1.twinx()
ax2.set_yscale("log")  # Set right y-axis to log scale
right_color = "purple"
ax2.plot(MWE, scaled_number, label="Scaled Number", color=right_color, marker="x", linestyle='-')
ax2.set_ylabel("Scaled Number", color=right_color)
ax2.tick_params(axis='y', colors=right_color)  # Set tick colors on the right y-axis to match
ax2.spines['right'].set_color(right_color)     # Set right y-axis spine color to match

# Combine legends from both axes
lines, labels = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines + lines2, labels + labels2, loc="upper center", bbox_to_anchor=(0.5, 0.95), fontsize="small", ncol=1, frameon=False)

# Show plot
plt.title("Production Rates and Scaled Number vs MWE (Log Scale)")
plt.show()

# %%
import pandas as pd
import numpy as np
from io import StringIO
import matplotlib.pyplot as plt

data_plot1="""
0	0
1.076580469	4.34E-06
1.195683485	5.56E-06
1.314786501	7.25E-06
1.552992533	1.22E-05
1.61254404	9.42E-06
1.672095548	1.58E-05
1.91030158	2.56E-05
1.969853088	1.88E-05
2.029404596	3.26E-05
2.088956104	9.65E-06
2.148507612	4.17E-05
2.267610627	5.40E-05
2.505816659	6.87E-05
2.744022691	8.43E-05
3.04178023	1.05E-04
3.518192293	1.26E-04
4.17325888	1.45E-04
4.887876975	1.57E-04
5.60249507	1.60E-04
6.02040001	1.46E-04
6.317113164	1.59E-04
7.031731259	1.53E-04
7.746349354	1.47E-04
8.460967449	1.40E-04
9.175585544	1.32E-04
9.890203638	1.25E-04
10.60482173	1.16E-04
11.31943983	1.08E-04
12.03405792	1.01E-04
12.74867602	9.53E-05
13.46329411	8.95E-05
14.17791221	8.47E-05
14.8925303	8.03E-05
15.6071484	7.64E-05
16.32176649	7.19E-05
17.03638459	6.70E-05
17.75100268	6.18E-05
18.46562078	5.61E-05
19.18023887	5.00E-05
19.89485697	4.53E-05
20.60947506	4.12E-05
21.32409316	3.75E-05
22.03871125	3.39E-05
22.75332934	3.03E-05
23.46794744	2.71E-05
24.18256553	2.44E-05
24.89718363	2.19E-05
25.61180172	1.98E-05
26.32641982	1.81E-05
27.04103791	1.64E-05
27.75565601	1.49E-05
28.4702741	1.32E-05
29.1848922	1.16E-05
29.89951029	1.00E-05
30.61412839	8.89E-06
31.32874648	7.89E-06
32.04336458	6.91E-06
32.75798267	6.04E-06
33.47260077	5.22E-06
34.18721886	4.55E-06
34.78273394	4.10E-06
"""
# Load the data into a DataFrame
data_io = StringIO(data_plot1)
df = pd.read_csv(data_io, delim_whitespace=True, header=None)

# Assign column names
df.columns = ['X', 'Y']

# Display the DataFrame (optional)
#print("DataFrame:\n", df.to_string(index=False))

# Create the plot
plt.figure(figsize=(10, 6))
plt.scatter(df['X'], df['Y'], color='blue', marker='o')

# Set logarithmic scale for y-axis
plt.yscale("log")

# Labeling axes
plt.xlabel("X values")
plt.ylabel("Y values (log scale)")
plt.title("Scatter Plot of Provided Data")

# Show grid
plt.grid(True, which='both', linestyle='--', linewidth=0.5)

# Show plot
plt.show()
